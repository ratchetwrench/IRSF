# %%
import numpy as np
import pandas as pd

countries = ['USA', 'GB', 'RU']
pareto_shape = 1.

prob = np.random.pareto(pareto_shape, len(countries))

prob /= np.sum(prob)

print(prob)
print(np.random.choice(countries, p=prob))
# Out:
# [ 0.96489217  0.02445678  0.01065105]
# USA

# %%
countries = pd.read_json('/Users/davidwrench/Projects/PhreakWatch-v1/phreakwatch/data/countries.json')

americas = countries[countries["region"] == "Americas"]

americas
# Out:
#                                           altSpellings       area  \
# 0                                                 [AW]      180.0
# 3                                                 [AI]       91.0
# 8        [AR, Argentine Republic, República Argentina]  2780400.0
# 13                                                [AG]      442.0
# 24                   [BS, Commonwealth of the Bahamas]    13943.0
# 26   [BL, St. Barthelemy, Collectivity of Saint Bar...       21.0
# 28                                                [BZ]    22966.0
# 29   [BM, The Islands of Bermuda, The Bermudas, Som...       54.0
# 30   [BO, Buliwya, Wuliwya, Bolivia, Plurinational ...  1098581.0
# 31   [BR, Brasil, Federative Republic of Brazil, Re...  8515767.0
# 32                                                [BB]      430.0
# 38                                                [CA]  9984670.0
# 41         [CL, Republic of Chile, República de Chile]   756102.0
# ...
